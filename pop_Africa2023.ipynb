# %% [markdown]
# <a href="https://colab.research.google.com/github/MbuyiseloNtando/Flights/blob/main/pop_Africa2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

#Site URL
url ='https://en.wikipedia.org/wiki/List_of_African_countries_by_population'

# %%
try:
    page = requests.get(url)
except Exception as e:
    print('Error downloading page: ',e)

soup = BeautifulSoup(page.text, 'html.parser')

# %%
# Find all tables in the webpage
tables = soup.find_all('table')

# %%
import pandas as pd

dfs = []  # This will contain all dataframes
for table in tables:
    dfs.append(pd.read_html(str(table))[0])

pop = dfs[0]
pop.columns = gdp.columns.get_level_values(0)

# %%
pop.head()
# Out:
#   Unnamed: 0   Country % Africa  Africa population[4] % growth  \
# 0          1   Nigeria    15.3%             223804632     2.4%
# 1          2  Ethiopia     8.7%             126527060     2.6%
# 2          3     Egypt     7.7%             111942661     1.6%
# 3          4  DR Congo     7.0%             102262809     3.3%
# 4          5  Tanzania     4.6%              69419073     3.0%
#
#    Official figure   Official date Unnamed: 7
# 0        216783400  21 Mar 2022[5]        NaN
# 1        107334000   1 Jul 2023[6]        NaN
# 2        102060688   1 Jul 2021[7]        [a]
# 3         95370000   1 Jul 2019[8]        NaN
# 4         61741120  23 Aug 2022[9]        NaN

# %%
df = pd.DataFrame(pop)

# %%
df.drop( columns = ['Unnamed: 0', '% Africa', 'Africa population[4]', '% growth', 'Official date', 'Unnamed: 7'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          56 non-null     object
#  1   Official figure  56 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %%
df.to_csv('pop_Africa2023.csv', index=False)
#/content/pop_Africa2023.csv
